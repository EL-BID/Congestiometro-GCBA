# %%
from io import StringIO
import gc
import csv
import json 
from time import sleep
from datetime import datetime, timedelta

import pandas as pd

from shapely.geometry import LineString

import vertica_python
import psycopg2
from sqlalchemy import create_engine

from io import StringIO
import gc
import csv
import json
from time import sleep
from datetime import datetime, timedelta

import pandas as pd

from shapely.geometry import LineString
from shapely.wkt import loads

import vertica_python
import psycopg2
from sqlalchemy import create_engine

# %%
postgres_configuration = {
    "host": "localhost",
    "port": 5432,
    "user": "postgres",
    "password": "congestiometro",
    "dbname": "postgres"
}
postgres_conn = psycopg2.connect(**postgres_configuration)
engine = create_engine('postgresql+psycopg2://postgres:congestiometro@localhost:5432/postgres')

# %%
def vertica_iterator(slice_start):
    sleep_time = 1 
    last_n_rows = 0
    with open("./sql/vertica_query.sql") as query_string:
        q = query_string.read()
        with vertica_conn.cursor() as cursor:
            while True:
                lastUpdate = cursor.execute("select max(lastUpdateMillis) from public.Jams").fetchone()[0]
                print(f"{datetime.now()}: Vertica last update: {pd.to_datetime(lastUpdate, unit='ms' ) - timedelta(hours=3)}")
                print(f"{datetime.now()}: Executing query...")
                cursor.execute(q, {'slice_start': slice_start})
                print(f"{datetime.now()}: Query executing ...")
                cols = [d.name for d in cursor.description]
                i = 0
                for i, c in enumerate(cursor.iterate()):
                    row = dict(zip(cols, c))
                    yield row
                if i < 10 + last_n_rows:
                    sleep_time = max(1, sleep_time * 2)
                elif i > 100 + last_n_rows:
                    sleep_time = max(1, sleep_time / 2)
                yield None
                last_n_rows = i
                print(f"{datetime.now()}: Query shielded {i + 1} rows")
                print(f"{datetime.now()}: Sleeping {sleep_time} seconds...")
                vertica_conn.commit()
                sleep(sleep_time)
                slice_start = max(row["lastUpdate"] - timedelta(seconds=1), slice_start)

# %%
lines = pd.read_sql("SELECT street_id, line_id, line FROM jam_lines", engine).set_index("line")
slice_start = pd.read_sql("SELECT coalesce(max(end_timestamp), make_date(1970, 1, 1)) FROM jams", engine).iloc[0,0]
iterator = vertica_iterator(slice_start)
total_rows = 0
i = 0
slice_start
# Out:
# Timestamp('1970-01-01 00:00:00')

# %%
print(f"{datetime.now()}: Initializing DB")
admin_levels = pd.read_csv("./barrios_badata_wgs84.csv")
admin_levels.index = admin_levels.index + 1
admin_levels["greater_admin_level_id"] = admin_levels["COMUNA"].astype(int)
admin_levels["greater_admin_level_name"] = admin_levels[
    "greater_admin_level_id"
].apply(lambda x: f"comuna {x}")
admin_levels["lower_admin_level_id"] = admin_levels.index
admin_levels["lower_admin_level_name"] = admin_levels["BARRIO"].str.lower()
admin_levels["shape"] = admin_levels["WKT"].apply(lambda x: loads(x).wkb_hex)
admin_levels["lines_ids"] = "[]"
admin_levels["streets_ids"] = "[]"
admin_levels["last_update"] = datetime.now()

buffer = StringIO()
admin_levels[
    [
        "greater_admin_level_id",
        "greater_admin_level_name",
        "lower_admin_level_id",
        "lower_admin_level_name",
        "lines_ids",
        "streets_ids",
        "shape",
        "last_update",
    ]
].to_csv(buffer, header=False, index=False, sep="\t")
buffer.seek(0)
with postgres_conn.cursor() as cursor:
    cursor.copy_from(buffer, "admin_levels")
    postgres_conn.commit()

print(f"{datetime.now()}: Getting lines")
with vertica_conn.cursor() as cursor:
    cursor.execute(
        "SELECT line_json AS line, min(street) as street_base_name, max(roadType) as street_type from public.Jams group by 1"
    )
    lines = pd.DataFrame(
        cursor.fetchall(), columns=[d.name for d in cursor.description]
    )
lines["line"] = lines["line"].apply(
    lambda x: LineString([(s["x"], s["y"]) for s in json.loads(x)]).wkb_hex
)
lines = lines[lines.street_base_name.str.strip().str.len() > 3]

buffer = StringIO()
lines[["street_base_name", "line", "street_type"]].to_csv(
    buffer, header=False, index=False, sep="\t"
)
buffer.seek(0)
print(f"{datetime.now()}: Filtering lines")
with postgres_conn.cursor() as cursor:
    cursor.execute("DROP TABLE IF EXISTS public.temp_jam_lines")
    cursor.execute(
        """
    CREATE TABLE public.temp_jam_lines (
        street_base_name text,
        line geometry(LINESTRING),
        street_type integer
    )
    """
    )
    cursor.copy_from(buffer, "temp_jam_lines")
    postgres_conn.commit()

    poly = pd.read_sql(
        "select ST_asTEXT(ST_Buffer(ST_MakePolygon(St_ExteriorRing(St_union(shape))), 0.0001)) as shape from admin_levels",
        engine,
    ).iloc[0, 0]
    lines = pd.read_sql(
        f"""
        SELECT *, degrees(ST_Azimuth(ST_StartPoint(line), ST_EndPoint(line))) as bearing
        from public.temp_jam_lines
        where st_contains('{poly}'::geometry, line)
    """,
        engine,
    )
    cursor.execute("DROP TABLE IF EXISTS public.temp_jam_lines")
    postgres_conn.commit()
lines["sense"] = (((lines.bearing // 45) + 1) % 8) // 2
lines["direction"] = lines["sense"] % 2
lines = lines.drop("direction", axis=1).join(
    pd.crosstab(lines.street_base_name, lines.direction)
    .idxmax(axis=1)
    .rename("direction"),
    on="street_base_name",
)
lines["sense_ns"] = pd.Series(" (S)", index=range(lines.shape[0])).where(
    (lines.bearing > 90) & (lines.bearing < (90 * 3)), " (N)"
)
lines["sense_ew"] = pd.Series(" (O)", index=range(lines.shape[0])).where(
    (lines.bearing > 180), " (E)"
)
lines["street_sufix"] = lines["sense_ns"].where(
    lines["direction"] == 0, lines["sense_ew"]
)
lines = lines.join(
    lines.groupby("street_base_name").street_sufix.nunique().rename("is2way") > 1,
    on="street_base_name",
)
lines["street_sufix"] = lines["street_sufix"].where(lines["is2way"], "")
lines["street_name"] = lines["street_base_name"]
lines["street_id"] = (
    (lines["street_name"] + lines["street_sufix"]).astype("category").cat.codes
)
lines["line_id"] = lines["line"].astype("category").cat.codes
lines["last_update"] = datetime.now()

buffer = StringIO()
lines[["street_id", "line"]].to_csv(buffer, header=False, index=False, sep="\t")
buffer.seek(0)
print(f"{datetime.now()}: Processing streets")
with postgres_conn.cursor() as cursor:
    cursor.execute("DROP TABLE IF EXISTS public.temp_streets")
    cursor.execute(
        """
    CREATE TABLE public.temp_streets (
        street_id integer,
        line geometry(LINESTRING)
    )
    """
    )
    cursor.copy_from(buffer, "temp_streets")
    cursor.execute(
        "SELECT street_id, ST_union(line) as line from public.temp_streets group by 1"
    )
    streets = pd.DataFrame(
        cursor.fetchall(), columns=[d.name for d in cursor.description]
    )
    cursor.execute("DROP TABLE IF EXISTS public.temp_streets")
    postgres_conn.commit()

streets = streets.join(
    lines.drop_duplicates(["street_id"]).set_index("street_id")[
        [
            "street_type",
            "street_base_name",
            "street_name",
            "street_sufix",
            "last_update",
        ]
    ],
    on="street_id",
)

buffer = StringIO()
streets[
    [
        "street_id",
        "street_type",
        "street_base_name",
        "street_name",
        "street_sufix",
        "line",
        "last_update",
    ]
].to_csv(buffer, header=False, index=False, sep="\t")
buffer.seek(0)
with postgres_conn.cursor() as cursor:
    cursor.copy_from(buffer, "streets")
    postgres_conn.commit()
del streets

buffer = StringIO()
lines[["line_id", "street_id", "line", "last_update"]].to_csv(
    buffer, header=False, index=False, sep="\t"
)
buffer.seek(0)
with postgres_conn.cursor() as cursor:
    cursor.copy_from(buffer, "jam_lines")
    postgres_conn.commit()

print(f"{datetime.now()}: Adding lines and streets to admin_levels")
with postgres_conn.cursor() as cursor:
    cursor.execute("DELETE FROM admin_levels")
    postgres_conn.commit()

lines_ids = []
streets_ids = []

for shape in admin_levels["WKT"]:
    lines = pd.read_sql(
        f"""
        SELECT DISTINCT line_id, street_id
        from public.jam_lines
        where st_contains(st_buffer('{shape}', 0.0001), line)
    """,
        engine,
    )
    lines_ids.append(json.dumps(lines.line_id.unique().tolist()))
    streets_ids.append(json.dumps(lines.street_id.unique().tolist()))

admin_levels["lines_ids"] = lines_ids
admin_levels["streets_ids"] = streets_ids

admin_levels[
    [
        "greater_admin_level_id",
        "greater_admin_level_name",
        "lower_admin_level_id",
        "lower_admin_level_name",
        "lines_ids",
        "streets_ids",
        "shape",
        "last_update",
    ]
].to_sql("admin_levels", engine, if_exists="append", index=False)

lines = pd.read_sql(
    "SELECT street_id, line_id, line FROM jam_lines", engine
).set_index("line")
# Out:
# 2022-06-15 18:46:17.079856: Initializing DB
# 2022-06-15 18:46:17.296393: Getting lines
# 2022-06-15 18:47:18.241856: Filtering lines
# 2022-06-15 18:47:31.455867: Processing streets
# 2022-06-15 18:50:20.854136: Adding lines and streets to admin_levels

# %%
cols = ["uuid","line_id","start_timestamp","end_timestamp",
        "hour","is_working_day","delay","length","speed","level"]
rows = {}
for i, row in enumerate(iterator):
    if row is None: break
    try:
        row["line"] = LineString([(s['x'], s['y']) for s in json.loads(row['line'])]).wkb_hex  
        row["street_id"] = int(lines.loc[row["line"], "street_id"])
        row["line_id"] = int(lines.loc[row["line"], "line_id"])
        row["is_working_day"] = int(row["is_working_day"])
        row["hour"] = str(set(pd.Series(pd.date_range(row["start_timestamp"], row["end_timestamp"],
                                                      freq='H')).dt.hour.tolist()))
        rows[row["uuid"]] = [row[c] for c in cols]
        if len(rows) % 500000 == 0:
            print(f"{datetime.now()}: Read {len(rows)} rows of initial db load. Initial iterator yielded {i + 1}")
    except:
        continue
total_rows = len(rows)
print(f"{datetime.now()}: Have {len(rows)} rows for initial db load")
buffer = StringIO()
writer = csv.writer(buffer, delimiter="\t")
for uuid in list(rows.keys()):
    writer.writerow(rows[uuid])
    del rows[uuid]
print(f"{datetime.now()}: Executing insert of {total_rows} rows. Initial iterator yielded {i + 1}")
with postgres_conn.cursor() as cursor:
    buffer.seek(0)
    cursor.copy_from(buffer, "jams")
    postgres_conn.commit()
print(f"{datetime.now()}: Initial db load done.")
del buffer
gc.collect()

# %%
with open("./sql/posgis_insert.sql") as insert_query:
    q = insert_query.read().replace(") s", ")s")
    with postgres_conn.cursor() as cursor:
        rows = []
        for j, row in enumerate(iterator):
            try:
                row["line"] = LineString([(s['x'], s['y']) for s in json.loads(row['line'])]).wkb_hex  
                row["street_id"] = int(lines.loc[row["line"], "street_id"])
                row["line_id"] = int(lines.loc[row["line"], "line_id"])
                row["is_working_day"] = int(row["is_working_day"])
                row["hour"] = str(set(pd.Series(pd.date_range(row["start_timestamp"], row["end_timestamp"],
                                                      freq='H')).dt.hour.tolist()))
                rows.append(row)
            except:
                pass
            if len(rows) < 10: continue
            if (row is None ) or (len(rows) % 10000 == 0):
                total_rows += len(rows)
                last_timestamp = rows[-1]["lastUpdate"]
                print(f"{datetime.now()}: Executing insert of {len(rows)}. Last known date {last_timestamp}. Total so far {total_rows}. Iterator yielded {j + i + 1}")
                cursor.executemany(q, rows)
                postgres_conn.commit()
                rows = []
# Out:
# 2022-06-07 12:18:52.090832: Vertica last update: 2022-06-07 12:18:03.265000
# 2022-06-07 12:18:52.092839: Executing query...
# 2022-06-07 12:19:06.755572: Query executing ...
# 2022-06-07 12:19:09.172153: Executing insert of 10000. Last known date 2022-06-07 12:18:03. Total so far 10000. Iterator yielded 10067
# 2022-06-07 12:19:24.094017: Executing insert of 397. Last known date 2022-06-07 12:18:03. Total so far 10397. Iterator yielded 10465
# 2022-06-07 12:19:24.649231: Query shielded 10464 rows
# 2022-06-07 12:19:24.649231: Sleeping 1 seconds...
# 2022-06-07 12:19:25.856309: Vertica last update: 2022-06-07 12:19:04.665000
# 2022-06-07 12:19:25.857310: Executing query...
# 2022-06-07 12:19:40.031666: Query executing ...
# 2022-06-07 12:19:40.159645: Executing insert of 475. Last known date 2022-06-07 12:18:03. Total so far 10872. Iterator yielded 10941
# 2022-06-07 12:19:40.824607: Query shielded 475 rows
# 2022-06-07 12:19:40.824607: Sleeping 2 seconds...
# 2022-06-07 12:19:43.023928: Vertica last update: 2022-06-07 12:19:04.665000
# 2022-06-07 12:19:43.024927: Executing query...
# 2022-06-07 12:19:57.065572: Query executing ...
# 2022-06-07 12:19:57.214278: Executing insert of 475. Last known date 2022-06-07 12:18:03. Total so far 11347. Iterator yielded 11417
# 2022-06-07 12:19:57.870927: Query shielded 475 rows
# 2022-06-07 12:19:57.870927: Sleeping 4 seconds...
# 2022-06-07 12:20:02.084719: Vertica last update: 2022-06-07 12:19:04.665000
# 2022-06-07 12:20:02.085722: Executing query...
# 2022-06-07 12:20:16.471073: Query executing ...
# 2022-06-07 12:20:16.670180: Executing insert of 515. Last known date 2022-06-07 12:18:03. Total so far 11862. Iterator yielded 11933
# 2022-06-07 12:20:17.344844: Query shielded 515 rows
# 2022-06-07 12:20:17.345846: Sleeping 4 seconds...
# 2022-06-07 12:20:21.534784: Vertica last update: 2022-06-07 12:19:04.665000
# 2022-06-07 12:20:21.535785: Executing query...
# 2022-06-07 12:20:35.382606: Query executing ...
# 2022-06-07 12:20:35.723679: Executing insert of 515. Last known date 2022-06-07 12:18:03. Total so far 12377. Iterator yielded 12449
# 2022-06-07 12:20:36.322325: Query shielded 515 rows
# 2022-06-07 12:20:36.322325: Sleeping 8 seconds...
# 2022-06-07 12:20:44.555620: Vertica last update: 2022-06-07 12:19:04.665000
# 2022-06-07 12:20:44.557001: Executing query...
# 2022-06-07 12:20:58.484752: Query executing ...
# 2022-06-07 12:20:58.653755: Executing insert of 515. Last known date 2022-06-07 12:18:03. Total so far 12892. Iterator yielded 12965
# 2022-06-07 12:20:59.522632: Query shielded 515 rows
# 2022-06-07 12:20:59.523635: Sleeping 16 seconds...
# 2022-06-07 12:21:15.749143: Vertica last update: 2022-06-07 12:21:07.624000
# 2022-06-07 12:21:15.750150: Executing query...
# 2022-06-07 12:21:29.864402: Query executing ...
# 2022-06-07 12:21:30.038671: Executing insert of 555. Last known date 2022-06-07 12:21:08. Total so far 13447. Iterator yielded 13521
# 2022-06-07 12:21:30.945446: Query shielded 555 rows
# 2022-06-07 12:21:30.946442: Sleeping 16 seconds...
# 2022-06-07 12:21:47.162030: Vertica last update: 2022-06-07 12:21:07.624000
# 2022-06-07 12:21:47.163027: Executing query...
# 2022-06-07 12:22:01.353183: Query executing ...
# 2022-06-07 12:22:01.613770: Executing insert of 463. Last known date 2022-06-07 12:21:08. Total so far 13910. Iterator yielded 13985
# 2022-06-07 12:22:02.221541: Query shielded 463 rows
# 2022-06-07 12:22:02.221541: Sleeping 32 seconds...
# 2022-06-07 12:22:34.441132: Vertica last update: 2022-06-07 12:22:09.051000
# 2022-06-07 12:22:34.442134: Executing query...
# 2022-06-07 12:22:48.494229: Query executing ...
# 2022-06-07 12:22:49.124830: Executing insert of 492. Last known date 2022-06-07 12:22:09. Total so far 14402. Iterator yielded 14478
# 2022-06-07 12:22:49.799873: Query shielded 492 rows
# 2022-06-07 12:22:49.799873: Sleeping 32 seconds...
# 2022-06-07 12:23:22.004247: Vertica last update: 2022-06-07 12:22:09.051000
# 2022-06-07 12:23:22.005264: Executing query...
# 2022-06-07 12:23:36.055232: Query executing ...
# 2022-06-07 12:23:36.293498: Executing insert of 488. Last known date 2022-06-07 12:22:09. Total so far 14890. Iterator yielded 14968
# 2022-06-07 12:23:37.092824: Query shielded 489 rows
# 2022-06-07 12:23:37.093824: Sleeping 64 seconds...
# 2022-06-07 12:24:41.283221: Vertica last update: 2022-06-07 12:24:11.527000
# 2022-06-07 12:24:41.298846: Executing query...
# 2022-06-07 12:24:55.510649: Query executing ...
# 2022-06-07 12:24:55.666893: Executing insert of 509. Last known date 2022-06-07 12:22:09. Total so far 15399. Iterator yielded 15478
# 2022-06-07 12:24:56.309845: Query shielded 509 rows
# 2022-06-07 12:24:56.309845: Sleeping 64 seconds...
# 2022-06-07 12:26:00.529107: Vertica last update: 2022-06-07 12:25:13.035000
# 2022-06-07 12:26:00.531385: Executing query...
# 2022-06-07 12:26:14.879839: Query executing ...
# 2022-06-07 12:26:15.137684: Executing insert of 582. Last known date 2022-06-07 12:24:12. Total so far 15981. Iterator yielded 16061
# 2022-06-07 12:26:16.279061: Query shielded 582 rows
# 2022-06-07 12:26:16.280063: Sleeping 64 seconds...
# 2022-06-07 12:27:20.494729: Vertica last update: 2022-06-07 12:27:15.627000
# 2022-06-07 12:27:20.496905: Executing query...
# 2022-06-07 12:27:34.560013: Query executing ...
# 2022-06-07 12:27:34.715016: Executing insert of 547. Last known date 2022-06-07 12:27:16. Total so far 16528. Iterator yielded 16609
# 2022-06-07 12:27:35.825544: Query shielded 547 rows
# 2022-06-07 12:27:35.826511: Sleeping 128 seconds...
# 2022-06-07 12:29:44.023392: Vertica last update: 2022-06-07 12:29:18.069000
# 2022-06-07 12:29:44.024393: Executing query...
# 2022-06-07 12:29:58.224119: Query executing ...
# 2022-06-07 12:29:58.731151: Executing insert of 534. Last known date 2022-06-07 12:28:17. Total so far 17062. Iterator yielded 17144
# 2022-06-07 12:29:59.460825: Query shielded 534 rows
# 2022-06-07 12:29:59.460825: Sleeping 256 seconds...
# 2022-06-07 12:34:15.682073: Vertica last update: 2022-06-07 12:34:23.808000
# 2022-06-07 12:34:15.682073: Executing query...
# 2022-06-07 12:34:30.194373: Query executing ...
# 2022-06-07 12:34:30.458794: Executing insert of 655. Last known date 2022-06-07 12:34:24. Total so far 17717. Iterator yielded 17801
# 2022-06-07 12:34:31.334724: Query shielded 656 rows
# 2022-06-07 12:34:31.334724: Sleeping 128.0 seconds...
# 2022-06-07 12:36:39.537989: Vertica last update: 2022-06-07 12:36:26.386000
# 2022-06-07 12:36:39.553614: Executing query...
# 2022-06-07 12:36:53.689539: Query executing ...
# 2022-06-07 12:36:53.845789: Executing insert of 500. Last known date 2022-06-07 12:34:24. Total so far 18217. Iterator yielded 18302
# 2022-06-07 12:36:54.511932: Query shielded 500 rows
# 2022-06-07 12:36:54.511932: Sleeping 256.0 seconds...
# 2022-06-07 12:41:10.709980: Vertica last update: 2022-06-07 12:40:31.572000
# 2022-06-07 12:41:10.709980: Executing query...
# 2022-06-07 12:41:25.054447: Query executing ...
# 2022-06-07 12:41:25.331582: Executing insert of 676. Last known date 2022-06-07 12:37:28. Total so far 18893. Iterator yielded 18981
# 2022-06-07 12:41:26.255782: Query shielded 678 rows
# 2022-06-07 12:41:26.255782: Sleeping 128.0 seconds...
# 2022-06-07 12:43:34.515976: Vertica last update: 2022-06-07 12:43:35.101000
# 2022-06-07 12:43:34.515976: Executing query...
# 2022-06-07 12:43:48.836353: Query executing ...
# 2022-06-07 12:43:49.008231: Executing insert of 645. Last known date 2022-06-07 12:42:34. Total so far 19538. Iterator yielded 19631
# 2022-06-07 12:43:49.792503: Query shielded 649 rows
# 2022-06-07 12:43:49.792503: Sleeping 256.0 seconds...
# 2022-06-07 12:48:05.955973: Vertica last update: 2022-06-07 12:47:41.331000
# 2022-06-07 12:48:05.955973: Executing query...
# 2022-06-07 12:48:20.299457: Query executing ...
# 2022-06-07 12:48:20.482837: Executing insert of 654. Last known date 2022-06-07 12:46:40. Total so far 20192. Iterator yielded 20289
# 2022-06-07 12:48:21.317519: Query shielded 657 rows
# 2022-06-07 12:48:21.317519: Sleeping 512.0 seconds...
# 2022-06-07 12:56:53.562827: Vertica last update: 2022-06-07 12:56:52.052000
# 2022-06-07 12:56:53.562827: Executing query...
# 2022-06-07 12:57:07.720695: Query executing ...
# 2022-06-07 12:57:07.946656: Executing insert of 761. Last known date 2022-06-07 12:49:44. Total so far 20953. Iterator yielded 21053
# 2022-06-07 12:57:09.059205: Query shielded 763 rows
# 2022-06-07 12:57:09.059205: Sleeping 256.0 seconds...
# 2022-06-07 13:01:25.330309: Vertica last update: 2022-06-07 13:00:56.613000
# 2022-06-07 13:01:25.330309: Executing query...
# 2022-06-07 13:01:39.487133: Query executing ...
# 2022-06-07 13:01:39.705893: Executing insert of 793. Last known date 2022-06-07 12:58:54. Total so far 21746. Iterator yielded 21850
# 2022-06-07 13:01:40.740627: Query shielded 796 rows
# 2022-06-07 13:01:40.740627: Sleeping 256.0 seconds...
# 2022-06-07 13:05:56.930242: Vertica last update: 2022-06-07 13:06:02.580000
# 2022-06-07 13:05:56.945873: Executing query...
# 2022-06-07 13:06:11.124459: Query executing ...
# 2022-06-07 13:06:11.322086: Executing insert of 620. Last known date 2022-06-07 13:05:01. Total so far 22366. Iterator yielded 22474
# 2022-06-07 13:06:12.191718: Query shielded 623 rows
# 2022-06-07 13:06:12.191718: Sleeping 512.0 seconds...
# 2022-06-07 13:14:44.423501: Vertica last update: 2022-06-07 13:14:12.854000
# 2022-06-07 13:14:44.423501: Executing query...
# 2022-06-07 13:14:58.531505: Query executing ...
# 2022-06-07 13:14:58.718984: Executing insert of 680. Last known date 2022-06-07 13:13:11. Total so far 23046. Iterator yielded 23157
# 2022-06-07 13:14:59.712651: Query shielded 682 rows
# 2022-06-07 13:14:59.712651: Sleeping 512.0 seconds...
# 2022-06-07 13:23:31.964144: Vertica last update: 2022-06-07 13:23:23.352000
# 2022-06-07 13:23:31.964144: Executing query...
# 2022-06-07 13:23:46.124105: Query executing ...
# 2022-06-07 13:23:46.306067: Executing insert of 737. Last known date 2022-06-07 13:23:23. Total so far 23783. Iterator yielded 23899
# 2022-06-07 13:23:47.348859: Query shielded 741 rows
# 2022-06-07 13:23:47.348859: Sleeping 512.0 seconds...
# 2022-06-07 13:32:19.551637: Vertica last update: 2022-06-07 13:31:31.780000
# 2022-06-07 13:32:19.551637: Executing query...
# 2022-06-07 13:32:34.297587: Query executing ...
# 2022-06-07 13:32:34.495722: Executing insert of 705. Last known date 2022-06-07 13:29:30. Total so far 24488. Iterator yielded 24609
# 2022-06-07 13:32:35.481480: Query shielded 709 rows
# 2022-06-07 13:32:35.481480: Sleeping 1024.0 seconds...
# 2022-06-07 13:49:39.667823: Vertica last update: 2022-06-07 13:48:52.195000
# 2022-06-07 13:49:39.667823: Executing query...
# 2022-06-07 13:49:54.353349: Query executing ...
# 2022-06-07 13:49:54.593028: Executing insert of 914. Last known date 2022-06-07 13:48:52. Total so far 25402. Iterator yielded 25538
# 2022-06-07 13:49:55.847523: Query shielded 928 rows
# 2022-06-07 13:49:55.847523: Sleeping 512.0 seconds...
# 2022-06-07 13:58:28.117663: Vertica last update: 2022-06-07 13:58:02.616000
# 2022-06-07 13:58:28.117663: Executing query...
# 2022-06-07 13:58:42.557571: Query executing ...
# 2022-06-07 13:58:42.859691: Executing insert of 652. Last known date 2022-06-07 13:56:01. Total so far 26054. Iterator yielded 26197
# 2022-06-07 13:58:43.789774: Query shielded 658 rows
# 2022-06-07 13:58:43.789774: Sleeping 1024.0 seconds...
# 2022-06-07 14:15:48.081704: Vertica last update: 2022-06-07 14:15:22.462000
# 2022-06-07 14:15:48.081704: Executing query...
# 2022-06-07 14:16:02.223714: Query executing ...
# 2022-06-07 14:16:02.479481: Executing insert of 873. Last known date 2022-06-07 14:15:22. Total so far 26927. Iterator yielded 27078
# 2022-06-07 14:16:04.085076: Query shielded 880 rows
# 2022-06-07 14:16:04.085076: Sleeping 512.0 seconds...
# 2022-06-07 14:24:36.305523: Vertica last update: 2022-06-07 14:24:21.423000
# 2022-06-07 14:24:36.321152: Executing query...
# 2022-06-07 14:24:51.244395: Query executing ...
# 2022-06-07 14:24:51.484616: Executing insert of 727. Last known date 2022-06-07 14:24:21. Total so far 27654. Iterator yielded 27811
# 2022-06-07 14:24:52.484647: Query shielded 732 rows
# 2022-06-07 14:24:52.484647: Sleeping 1024.0 seconds...
# 2022-06-07 14:41:56.723137: Vertica last update: 2022-06-07 14:41:52.574000
# 2022-06-07 14:41:56.735656: Executing query...
# 2022-06-07 14:42:10.968958: Query executing ...
# 2022-06-07 14:42:11.221266: Executing insert of 1012. Last known date 2022-06-07 14:39:50. Total so far 28666. Iterator yielded 28825
# 2022-06-07 14:42:12.648797: Query shielded 1013 rows
# 2022-06-07 14:42:12.648797: Sleeping 512.0 seconds...
# 2022-06-07 14:50:44.890819: Vertica last update: 2022-06-07 14:50:02.700000
# 2022-06-07 14:50:44.890819: Executing query...
# 2022-06-07 14:50:59.445699: Query executing ...
# 2022-06-07 14:50:59.674774: Executing insert of 785. Last known date 2022-06-07 14:49:02. Total so far 29451. Iterator yielded 29612
# 2022-06-07 14:51:00.656588: Query shielded 786 rows
# 2022-06-07 14:51:00.672224: Sleeping 1024.0 seconds...
